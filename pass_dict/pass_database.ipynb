# %%
import sys
sys.path.insert(0, "/nsls2/data/chx/shared/CHX_Software/packages/pass_dict/")
from pass_database import *

# %%
pass_functions?

# %% [markdown]
# ### load existing database:

# %%
load_pass_database?

# %%
pass_dict = load_pass_database(auto_load=False)

# %%
pass_dict

# %% [markdown]
# ### update database:

# %%
update_pass_database?

# %%
update_pass_database(update_dict='template',pass_dict='load')

# %%
update_dict = {'2025-1': {316793: {'username': 'chx_staff', 'alias': 'data security'},
                          316251: {'username': 'fluerasu', 'alias': 'ghost imaging'},
                          315259: {'username': 'petrash'},
                          317286: {'username': 'headrick'},
                          316448: {'username': 'he'},
                          3115532: {'username': 'zidovska'},
                          315366: {'username': 'lwiegart'},
                          317156: {'username': 'leheny'},
                          316089: {'username': 'cai'},
                          316457: {'username': 'koga'},
                          317365: {'username': 'xmchen'},
                          316948: {'username': 'beaucage'},
              }}
pass_dict = update_pass_database(pass_dict='load',update_dict=update_dict,autosave=True)
# Out:
# Found existing PASS database entry for cycle: 2025-1  pass_id: 316948   user:beaucage
# Overwrite existing entry? [y,n]: n
# skipping entry
# Database file already exists...saving backup with timestamp in /nsls2/data2/chx/shared/CHX_Software/packages/pass_dict/pass_database_backups/  as CHX_PASS_database_28_17:08:22_2025.json before overwriting existing file!
# Saved database as /nsls2/data2/chx/shared/CHX_Software/packages/pass_dict/CHX_PASS_database.json!

# %%
pass_dict

# %%
update_dict = {'2025-1':{315366:{'username':'lwiegart'}}}
pass_dict = update_pass_database(pass_dict='load',update_dict=update_dict,autosave=True)

# %% [markdown]
# ### find pass_id(s):

# %%
get_pass_id?

# %%
pass_id,pass_id_str,return_list = get_pass_id(cycle=[],username=None,alias='ghost imaging',pass_dict='load')

# %%
pass_id,pass_id_str,return_list

# %% [markdown]
# ### find information for a proposal by pass_id

# %%
get_proposal_info?

# %%
get_proposal_info(pass_id=316025,pass_dict='load')

# %% [markdown]
# ### remove an entry from the pass_dict:

# %%
remove_pass_dict_entry?

# %%
remove_pass_dict_entry(pass_dict='load',cycle=[],pass_id=999999,autosave=True)

# %% [markdown]
# ### saving PASS database (autosave is built into all functions abvove, which use this function)

# %%
save_pass_database?
