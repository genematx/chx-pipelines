# %%
import os
from termcolor import colored

jupyter_environment = None; machine = None
env = !env
try:
    if env.grep('SLURM_CLUSTER_NAME')[0].split('=')[1] == 'nsls2':
        machine = 'jupyter_hub'; jupyter_environment = 'standard'
except:
    try:
        machine = env.grep('HOSTNAME')[0].split('-')[1].split('.')[0]
        try:
            jupyter_environment = [s for s in env.grep('CONDA_PREFIX') if 'analysis' in s][0].split('/')[-1]
        except:
            print(os.getenv("CONDA_PREFIX"),machine)
            jupyter_environment = os.getenv("CONDA_PREFIX").split('/')[-1]
    except:
        print("Sorry, couldn't figure out what machine and environment this notebook is running on...'\nPlease apply fixes manually by uncommenting options in the cell below.")

###### Temporarily saving in alternate directories if analysis notebook is run by Radisoft ###############
if machine in ['jupyter_hub','srv1','srv2','srv3']: alternate_directory = None;pre='' 
else: 
    alternate_directory = '/nsls2/data/chx/assets/raydata/';print('Running notbook via RADIASOFT: changing output directory to ...chx/assets/raydata/...')
    machine = 'raydata'; jupyter_environment = 'standard';pre='presumably '

print(colored('%srunning on: %s   environment: %s\n'%(pre,machine,jupyter_environment),'green'))
###### SETTING THE BASE PATH TO THE ANALYSIS Directory  #############
_base_path_ = '/nsls2/data/chx/legacy/analysis/'
print(colored("setting '_base_path_' as %s"%_base_path_,'cyan'))
_base_path_pass_ = '/nsls2/data/chx/proposals/'
print(colored("setting '_base_path_pass_' as %s"%_base_path_pass_,'cyan'))
###### SETTING THE PATH TO Detector pixels masks and ROI masks  #############
_mask_path_ = '/nsls2/data/chx/shared/CHX_Setup/Detector_masks/'
print(colored("setting '_mask_path_' as %s\n"%_mask_path_,'cyan'))

# PyCHX_path: '/nsls2/data/chx/shared/CHX_Software/packages/PyCHX/'
# patches_path: '/nsls2/data/chx/shared/CHX_Software/packages/patches/'
############ ENVIRONMENT INDEPENDENT PATCHES ##################################################################################################################try:
try:
    # %run -i /nsls2/data/chx/shared/CHX_Software/packages/patches/roi_nr_2019_3_0_1.py
    print('ran "%run -i /nsls2/data/chx/shared/CHX_Software/packages/patches/roi_nr_2019_3_0_1.py" to fix ROI numbering for PHI-sliced data sets. Should get fixed in pyCHX...')
except:
    print('ERRROR: failed to run "%run -i /nsls2/data/chx/shared/CHX_Software/packages/patches/roi_nr_2019_3_0_1.py" -> ROI numbering for PHI-sliced datasets will not be handled correctly!!')

try:
    # %run -i /nsls2/data/chx/shared/CHX_Software/packages/patches/chx_outlier_detection.py
    print('ran "%run -i /nsls2/data/chx/shared/CHX_Software/packages/patches/chx_outlier_detection.py": this should become part of pyCHX.')
except:
    print('ERRROR: failed to run "%run -i /nsls2/data/chx/shared/CHX_Software/packages/patches/pyCHX_June2023/chx_outlier_detection.py" -> can only do data processing with "mask_outliers = False"!!')
    
try:
    # %run -i /nsls2/data/chx/shared/CHX_Software/packages/patches/fix_get_sid_filenames.py
    print('ran "%run -i /nsls2/data/chx/shared/CHX_Software/packages/patches/fix_get_sid_filenames.py": this should be fixed and re-deployed in pyCHX.')
except:
    print('ERRROR: failed to run "%run -i -i /nsls2/data/chx/shared/CHX_Software/packages/patches/fix_get_sid_filenames.py" -> get_sid_filenames() will not work in current environments"!!')
# %run -i /nsls2/data/chx/legacy/analysis/2018_3/lwiegart/development/mi_tmp_fix.py -> temporary fix for np.float depreciation in modestimage
    
############# ENVIRONMENT DEPENDENT PATCHES & SETTINGS #########################################################################################################
print(colored('\nenvironment dependent settings and patches:','magenta'))
if machine == 'jupyter_hub' or jupyter_environment in ["2023-3.2-py310-tiled","2024-1.0-py311-tiled-rc1"]:
    # %matplotlib inline
    print('using "%matplotlib inline" for plotting')
    try:
        # %run -i /nsls2/data/chx/shared/CHX_Software/packages/patches/polygonmask_fix.py
        print('ran "%run -i /nsls2/data/chx/shared/CHX_Software/packages/patches/polygonmask_fix.py".')
    except:
        print('ERRROR: failed to run "%run -i /nsls2/data/chx/shared/CHX_Software/packages/patches/development//polygonmask_fix.py" -> polygon masks will likely NOT work!!')
    try:
        # %run -i /nsls2/data/chx/shared/CHX_Software/packages/pyCHX/backups/chx_compress_05012024.py
        print('ran "%run -i /nsls2/data/chx/shared/CHX_Software/packages/pyCHX/backups/chx_compress_05012024.py": temporary fix for depreciated np.float.')
    except:
        print('ERRROR: failed to run "%run -i /nsls2/data/chx/shared/CHX_Software/packages/pyCHX/backups/chx_compress_05012024.py" -> fix for depreciated np.float NOT applied!!')
    try:
        # %run -i /nsls2/data/chx/shared/CHX_Software/packages/pyCHX/backups/chx_correlationc_05012024.py
        print('ran "%run -i /nsls2/data/chx/shared/CHX_Software/packages/pyCHX/backups/chx_correlationc_05012024.py": temporary fix for depreciated np.float.')
    except:
        print('ERRROR: failed to run "%run -i /nsls2/data/chx/shared/CHX_Software/packages/pyCHX/backups/chx_correlationc_05012024.py" -> fix for depreciated np.float NOT applied!!')    
    try:
        # %run -i /nsls2/data/chx/shared/CHX_Software/packages/pyCHX/backups/Create_Report_05012024.py
        print('ran "%run -i /nsls2/data/chx/shared/CHX_Software/packages/pyCHX/backups/Create_Report_05012024.py": temporary fix for depreciated np.float.')
    except:
        print('ERRROR: failed to run "%run -i /nsls2/data/chx/shared/CHX_Software/packages/pyCHX/backups/Create_Report_05012024.py" -> fix for depreciated np.float NOT applied!!') 
    try:
        # %run -i /nsls2/data/chx/shared/CHX_Software/packages/pyCHX/backups/xpcs_timepixel_05012024.py
        print('ran "%run -i /nsls2/data/chx/shared/CHX_Software/packages/pyCHX/backups/xpcs_timepixel_05012024.py": temporary fix for depreciated np.float.')
    except:
        print('ERRROR: failed to run "%run -i /nsls2/data/chx/shared/CHX_Software/packages/pyCHX/backups/xpcs_timepixel_05012024.py" -> fix for depreciated np.float NOT applied!!') 
    try:
        # %run -i /nsls2/data/chx/shared/CHX_Software/packages/pyCHX/backups/chx_generic_functions_05012024.py
        print('ran "%run -i /nsls2/data/chx/shared/CHX_Software/packages/pyCHX/backups/chx_generic_functions_05012024.py": temporary fix for depreciated np.float. np.int, collection.Iterable')
    except:
        print('ERRROR: failed to run "%run -i /nsls2/data/chx/shared/CHX_Software/packages/pyCHX/backups/chx_generic_functions_05012024.py" -> fix for depreciated np.float, np.int, collection.Iterable NOT applied!!') 

elif machine =='raydata': # keep raydata seperate, for noW it's running the same analysis-2019-3.0.1-chx environment as srv1,3 local 
    # %matplotlib inline
    print('using "%matplotlib inline" for plotting')

elif machine in ['srv1','srv2','srv3']:
    # %matplotlib notebook
    print('using "%matplotlib notebook" for plotting')
# Out:
# running on: jupyter_hub   environment: standard
#
# setting '_base_path_' as /nsls2/data/chx/legacy/analysis/
# setting '_mask_path_' as /nsls2/data/chx/shared/CHX_Setup/Detector_masks/
#
# ran "%run -i /nsls2/data/chx/shared/CHX_Software/packages/patches/roi_nr_2019_3_0_1.py" to fix ROI numbering for PHI-sliced data sets. Should get fixed in pyCHX...
# ran "%run -i /nsls2/data/chx/shared/CHX_Software/packages/patches/chx_outlier_detection.py": this should become part of pyCHX.
# ran "%run -i /nsls2/data/chx/shared/CHX_Software/packages/patches/fix_get_sid_filenames.py": this should be fixed and re-deployed in pyCHX.
#
# environment dependent settings and patches:
# using "%matplotlib inline" for plotting
# ran "%run -i /nsls2/data/chx/shared/CHX_Software/packages/patches/polygonmask_fix.py".
# OBJECT CACHE: Will use up to 121_695_745_228 bytes (15% of total physical RAM)
# ...
